# %%
import pandas as pd
from sklearn import preprocessing
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
p_le = preprocessing.LabelEncoder()

train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
######################
def clean(train): #clean the data to make it easier to use/read
    train = train.drop(["Ticket", "Name", "Cabin"], axis = 1)#get rid of useless columns, wont effect result
    
    #ensure numerical fields are all complete
    #if numerical field is left blank, replace with mean of column
    train.Age.fillna(train.Age.mean(), inplace = True)
    train.SibSp.fillna(train.SibSp.mean(), inplace = True)
    train.Parch.fillna(train.Parch.mean(), inplace = True)
    train.Fare.fillna(train.SibSp.mean(), inplace = True)
    train.Embarked.fillna("X", inplace = True)#if Embarked status left blank replace with "X" to represent no input
    train.Sex = p_le.fit_transform(train.Sex)#only actually want to transform data in test. train is used just to learn and reference
    test.Sex = p_le.transform(test.Sex)
    train.Embarked = p_le.fit_transform(train.Embarked)
    test.Embarked = p_le.transform(test.Embarked)
    return train

train = clean(train)
test = clean(test)

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0            1         0       3    1  22.000000      1      0   7.2500
# 1            2         1       1    0  38.000000      1      0  71.2833
# 2            3         1       3    0  26.000000      0      0   7.9250
# 3            4         1       1    0  35.000000      1      0  53.1000
# 4            5         0       3    1  35.000000      0      0   8.0500
# 5            6         0       3    1  29.699118      0      0   8.4583
# 6            7         0       1    1  54.000000      0      0  51.8625
# 7            8         0       3    1   2.000000      3      1  21.0750
# 8            9         1       3    0  27.000000      0      2  11.1333
# 9           10         1       2    0  14.000000      1      0  30.0708
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2
# 5         1
# 6         2
# 7         2
# 8         2
# 9         0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

a = train.drop("Survived", axis = 1)
b = train["Survived"]


a_train, a_val, b_train, b_val = train_test_split(a, b, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression(random_state=0, max_iter=1000).fit(a_train, b_train)

# %%
predictions = clf.predict(a_val)
from sklearn.metrics import accuracy_score
accuracy_score(b_val, predictions)
# Out:
# 0.8100558659217877

# %%
pred_output = clf.predict(test)
return_file = pd.DataFrame({"PassengerId": test['PassengerId'], "Survived": pred_output})
return_file.to_csv("Titanic_data_oup.csv")
